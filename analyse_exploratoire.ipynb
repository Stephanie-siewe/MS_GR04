# %%
##Import
import json
import glob
import pandas as pd

# %% [markdown]
# ## Chargement des fichiers json

# %%
# Liste pour stocker les données de tous les fichiers
all_data = []

# Parcourir tous les fichiers correspondants au format rawX.json
for file in sorted(glob.glob("tweet_data/raw*.json")):
    with open(file, "r", encoding="utf-8") as f:
        for line in f:
            try:
                data = json.loads(line.strip())  # Charger chaque ligne JSON
                all_data.append(data)
            except json.JSONDecodeError as e:
                print(f"Erreur de décodage JSON dans {file}: {e}")

# Vérification du nombre de tweets chargés
print(f"Nombre total d'entrées chargées : {len(all_data)}")
# Out:
# Nombre total d'entrées chargées : 401999

# %% [markdown]
# ## Conversion en dataframe pandas

# %%
df = pd.DataFrame(all_data)

# %%
display(df)
# Out:
#                created_date   current_time in_reply_to_status_id_str  \
# 0       2018-06-14 04:14:25  1528942465098                      None
# 1       2018-06-14 04:14:25  1528942465150                      None
# 2       2018-06-14 04:14:25  1528942465165                      None
# 3       2018-06-14 04:14:25  1528942465499                      None
# 4       2018-06-14 04:14:26  1528942466051                      None
# ...                     ...            ...                       ...
# 401994  2018-06-14 12:50:05  1528973405999                      None
# 401995  2018-06-14 12:50:06  1528973406022                      None
# 401996  2018-06-14 12:50:06  1528973406174                      None
# 401997  2018-06-14 12:50:06  1528973406201                      None
# 401998  2018-06-14 12:50:06  1528973406227                      None
#
#         in_reply_to_status_id                      created_at  \
# 0                         NaN  Thu Jun 14 02:14:24 +0000 2018
# 1                         NaN  Thu Jun 14 02:14:24 +0000 2018
# 2                         NaN  Thu Jun 14 02:14:24 +0000 2018
# 3                         NaN  Thu Jun 14 02:14:25 +0000 2018
# 4                         NaN  Thu Jun 14 02:14:25 +0000 2018
# ...                       ...                             ...
# 401994                    NaN  Thu Jun 14 10:50:05 +0000 2018
# 401995                    NaN  Thu Jun 14 10:50:05 +0000 2018
# 401996                    NaN  Thu Jun 14 10:50:05 +0000 2018
# 401997                    NaN  Thu Jun 14 10:50:05 +0000 2018
# 401998                    NaN  Thu Jun 14 10:50:05 +0000 2018
#
#        in_reply_to_user_id_str  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# ...                        ...
# 401994                    None
# 401995                    None
# 401996                    None
# 401997                    None
# 401998                    None
#
#                                                    source  \
# 0       <a href="http://twitter.com/download/iphone" r...
# 1       <a href="http://twitter.com/download/iphone" r...
# 2       <a href="http://twitter.com/#!/download/ipad" ...
# 3       <a href="http://twitter.com/download/iphone" r...
# 4       <a href="http://twitter.com/download/android" ...
# ...                                                   ...
# 401994  <a href="https://www.hootsuite.com" rel="nofol...
# 401995  <a href="http://instagram.com" rel="nofollow">...
# 401996  <a href="http://twitter.com/download/android" ...
# 401997  <a href="https://www.hootsuite.com" rel="nofol...
# 401998  <a href="http://twitter.com/download/iphone" r...
#
#                                          retweeted_status  retweet_count  \
# 0       {'extended_entities': {'media': [{'display_url...              0
# 1                                                     NaN              0
# 2       {'quoted_status': {'in_reply_to_status_id_str'...              0
# 3       {'extended_tweet': {'extended_entities': {'med...              0
# 4       {'extended_entities': {'media': [{'display_url...              0
# ...                                                   ...            ...
# 401994                                                NaN              0
# 401995                                                NaN              0
# 401996  {'in_reply_to_status_id_str': None, 'in_reply_...              0
# 401997                                                NaN              0
# 401998                                                NaN              0
#
#         retweeted  ...                                               user  \
# 0           False  ...  {'utc_offset': None, 'friends_count': 826, 'pr...
# 1           False  ...  {'utc_offset': None, 'friends_count': 686, 'pr...
# 2           False  ...  {'utc_offset': None, 'friends_count': 44, 'pro...
# 3           False  ...  {'utc_offset': None, 'friends_count': 3189, 'p...
# 4           False  ...  {'utc_offset': None, 'friends_count': 407, 'pr...
# ...           ...  ...                                                ...
# 401994      False  ...  {'utc_offset': None, 'friends_count': 63, 'pro...
# 401995      False  ...  {'utc_offset': None, 'friends_count': 198, 'pr...
# 401996      False  ...  {'utc_offset': None, 'friends_count': 175, 'pr...
# 401997      False  ...  {'utc_offset': None, 'friends_count': 119, 'pr...
# 401998      False  ...  {'utc_offset': None, 'friends_count': 320, 'pr...
#
#                                             quoted_status quoted_status_id  \
# 0                                                     NaN              NaN
# 1       {'extended_tweet': {'extended_entities': {'med...     1.007083e+18
# 2       {'in_reply_to_status_id_str': None, 'in_reply_...     1.007082e+18
# 3                                                     NaN              NaN
# 4                                                     NaN              NaN
# ...                                                   ...              ...
# 401994                                                NaN              NaN
# 401995                                                NaN              NaN
# 401996                                                NaN              NaN
# 401997                                                NaN              NaN
# 401998                                                NaN              NaN
#
#                                   quoted_status_permalink possibly_sensitive  \
# 0                                                     NaN                NaN
# 1       {'expanded': 'https://twitter.com/flubase/stat...              False
# 2       {'expanded': 'https://twitter.com/ESPNLosAngel...              False
# 3                                                     NaN                NaN
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 401994                                                NaN              False
# 401995                                                NaN              False
# 401996                                                NaN                NaN
# 401997                                                NaN              False
# 401998                                                NaN              False
#
#         display_text_range  quoted_status_id_str  \
# 0                      NaN                   NaN
# 1                  [0, 27]   1007083141671026689
# 2                      NaN   1007081758389620736
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ...                    ...                   ...
# 401994            [0, 140]                   NaN
# 401995                 NaN                   NaN
# 401996                 NaN                   NaN
# 401997            [0, 103]                   NaN
# 401998            [0, 140]                   NaN
#
#                                         extended_entities  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 401994                                                NaN
# 401995                                                NaN
# 401996                                                NaN
# 401997  {'media': [{'display_url': 'pic.twitter.com/kh...
# 401998                                                NaN
#
#                                            extended_tweet  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 401994  {'extended_entities': {'media': [{'display_url...
# 401995                                                NaN
# 401996                                                NaN
# 401997                                                NaN
# 401998  {'extended_entities': {'media': [{'display_url...
#
#        withheld_in_countries
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 401994                   NaN
# 401995                   NaN
# 401996                   NaN
# 401997                   NaN
# 401998                   NaN
#
# [401999 rows x 39 columns]

# %% [markdown]
# ## Qualité des données

# %%
## Affichage du schema du dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401999 entries, 0 to 401998
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   created_date               401999 non-null  object
#  1   current_time               401999 non-null  int64
#  2   in_reply_to_status_id_str  7764 non-null    object
#  3   in_reply_to_status_id      7764 non-null    float64
#  4   created_at                 401999 non-null  object
#  5   in_reply_to_user_id_str    10230 non-null   object
#  6   source                     401999 non-null  object
#  7   retweeted_status           258750 non-null  object
#  8   retweet_count              401999 non-null  int64
#  9   retweeted                  401999 non-null  bool
#  10  geo                        261 non-null     object
#  11  filter_level               401999 non-null  object
#  12  in_reply_to_screen_name    10230 non-null   object
#  13  is_quote_status            401999 non-null  bool
#  14  id_str                     401999 non-null  object
#  15  in_reply_to_user_id        10230 non-null   float64
#  16  favorite_count             401999 non-null  int64
#  17  id                         401999 non-null  int64
#  18  text                       401999 non-null  object
#  19  place                      8883 non-null    object
#  20  lang                       401999 non-null  object
#  21  quote_count                401999 non-null  int64
#  22  favorited                  401999 non-null  bool
#  23  coordinates                261 non-null     object
#  24  truncated                  401999 non-null  bool
#  25  timestamp_ms               401999 non-null  object
#  26  reply_count                401999 non-null  int64
#  27  entities                   401999 non-null  object
#  28  contributors               0 non-null       object
#  29  user                       401999 non-null  object
#  30  quoted_status              43870 non-null   object
#  31  quoted_status_id           43871 non-null   float64
#  32  quoted_status_permalink    43870 non-null   object
#  33  possibly_sensitive         202845 non-null  object
#  34  display_text_range         74666 non-null   object
#  35  quoted_status_id_str       43871 non-null   object
#  36  extended_entities          106992 non-null  object
#  37  extended_tweet             48889 non-null   object
#  38  withheld_in_countries      59 non-null      object
# dtypes: bool(4), float64(3), int64(6), object(26)
# memory usage: 108.9+ MB

# %%
## Données manquantes
df.isnull().sum()
# Out:
# created_date                      0
# current_time                      0
# in_reply_to_status_id_str    394235
# in_reply_to_status_id        394235
# created_at                        0
# in_reply_to_user_id_str      391769
# source                            0
# retweeted_status             143249
# retweet_count                     0
# retweeted                         0
# geo                          401738
# filter_level                      0
# in_reply_to_screen_name      391769
# is_quote_status                   0
# id_str                            0
# in_reply_to_user_id          391769
# favorite_count                    0
# id                                0
# text                              0
# place                        393116
# lang                              0
# quote_count                       0
# favorited                         0
# coordinates                  401738
# truncated                         0
# timestamp_ms                      0
# reply_count                       0
# entities                          0
# contributors                 401999
# user                              0
# quoted_status                358129
# quoted_status_id             358128
# quoted_status_permalink      358129
# possibly_sensitive           199154
# display_text_range           327333
# quoted_status_id_str         358128
# extended_entities            295007
# extended_tweet               353110
# withheld_in_countries        401940
# dtype: int64
